# %% [markdown]
# # Crime Stats Project Data Science Department

# %% [markdown]
# **Remember to add descriptions!**
#
# We looked at data from StatsSA about Gauteng citizen's perceptions of crime during 2016/2017.
#
# We were interested in examining:
# * how often people talk about crime
# * how safe people feel while doing certain activities
# * what measures people take to protect themselves, and
# * what types of crimes they have experienced in the last 5 years.

# %%
#Importing our dataframe and extracting Gauteng

import pandas as pd
import matplotlib.pyplot as plt
import pylab as pyl
import numpy as np

section = pd.read_csv('VOCS2016-2017-SECTION21TO28_F1.csv')
gautengS = section[section.prov == 7 ]

household = pd.read_csv('VOCS2016-2017-HOUSEHOLD_F1.csv')
gautengH = household[household.prov == 7 ]

# %% [markdown]
# ### Number of people surveyed per metro in Gauteng

# %%
# In this code we are looking at how many people were interviewed from each metro
# This is for section 21 to 28 and household

metrosS = gautengS.groupby('metro_code') .size() .reset_index(name = 'frq')
metrosS

metrosH = gautengH.groupby('metro_code') .size() .reset_index(name = 'frq')
metrosH

#do we need GP in the label if we are working with data from Gauteng only?
labels = ["GP - Non Metro", "GP - Ekurhuleni", "GP - City of Johannesburg", "GP - City of Tshwane"]
ax, bx = plt.subplots() #looks like you want a subplot - did you want to plot these two next to each other?

"""for i, v in enumerate(metros['frq']):
    ax.text(v + 3, i + .25, str(v),fontweight='bold')"""
#remember to delete unwanted / unused code

plt.barh(labels, metrosS['frq'])
plt.title('Number of People Surveyed (Crimes Experienced)')
plt.xlabel('Number of people')
plt.ylabel('Metros')
plt.show()

# This is for Household
plt.barh(labels, metrosH['frq'])
plt.title('Number of People Surveyed (Perception of Crime)')
plt.xlabel('Number of people')
plt.ylabel('Metros')
plt.show()

# %% [markdown]
# Need a new header here - e.g. Perceptions of crime and safety

# %%
CrimeTopic = gautengH.groupby('Q21topiccrime') .size()
CrimeTopic

CrimeTopic = CrimeTopic[0:2]

labels = ['Yes', 'No', ]
color = ['palegreen','crimson']

#show percentage for each group on the pie chart 

plt.pie(CrimeTopic, labels =labels, colors = color, autopct='%1.0f%%')
plt.title('How Many People Talk About Crime') #this is not a good title, because "yes" is not an answer to how many people talk about crime
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()

# %% [markdown]
# ### How Many People Are Scared Of Walking During The Day - Rather change the title to address a broader theme or make a statement about the content within this section ("How many people are scared" is not a stand-alone title.

# %%
walkingday = gautengH.groupby('Q29WalkDay') .size()
DayWalking = gautengS.groupby('Q21a7WalkDay') .size() 

#Here we combined the section 21 to 28 and household data of people who are scared of walking during the day
Household = walkingday[0:4]
Section = DayWalking[0:4]
plot = Household + Section

labels = ['Very safe ', 'Fairly safe', 'A bit unsafe ', 'Very unsafe']
color = ['#67DC2C','#C5DC2C','#FF8000','#FF0000', '#E0E0E0']

plt.pie(plot, labels =labels, autopct='%1.0f%%', colors = color)
plt.title('How Many People are afraid of walking during the day') #Better: How safe do people feel when walking durign day?
fig = plt.gcf()
fig.set_size_inches(10,10) #this is quite big: can you subplot these images so that we have all the graphs related to same topic in one row / section?
plt.show()

# %% [markdown]
# ### How Many People Are Scared Of Walking At Night

# %%
nightWalking = gautengS.groupby('Q21a6WalkDark') .size() 
walkingnight = gautengH.groupby('Q28WalkDark') .size()

#combining the two Section 21 to 28 and household
household = walkingnight[0:4]
section = nightWalking[0:4]
plot = household + section #what's the reasoning behind combining the two data sets?

labels = ['Very safe ', 'Fairly safe', 'A bit unsafe', 'Very unsafe']
color = ['#67DC2C','#C5DC2C','#FF8000','#FF0000', '#E0E0E0']

plt.pie(plot, labels =labels, autopct='%1.0f%%', colors = color )
plt.title('Do People Feel Safe Walking At Night ') #Better: How safe do people feel ...
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()

# %% [markdown]
# # Protection
#
# How many people in Gauteng are concerned about protecting themselves?
# How do they feel after getting the protection?
# Can we help them feel more secure?
#
# *very nice*

# %%
protection = gautengH[['Q321Home','Q322Vehicle', 'Q323Weapons', 'Q324PrivSecur', 'Q325SelfHelp', 'Q326Other']]

yes = protection[protection == 1] .count() .sum()
no  = protection[protection == 2] .count() .sum()
uns = protection[protection == 9] .count() .sum()

df = yes, no
labels = ['yes', 'no']
color = ['palegreen','crimson']

plt.pie(df, labels =labels, autopct='%1.0f%%', colors = color)
plt.title('How Many People have Taken Measures To Protect Themselves') #tweak title
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()

# %% [markdown]
# Remember to add in markdown sections explaining the data to the reader, this can also go further to include your own thoughts/ interpretations of the data, but make sure you make it clear what is data and what is speculation. eg:
#
# The Gauteng responders were quite conscious about crime. Half of people report talking about crime in the last two weeks. Althoug most people report feeling safe while walking in the day, most feel *unsafe* walking at night.

# %%
feelsafer = gautengH.groupby('Q33FeelSafer') .size()
feelsafer = feelsafer[0:2]

labels = ['Yes', 'No']
color = ['palegreen','crimson']

plt.pie(feelsafer, labels =labels, autopct='%1.0f%%', colors = color)
plt.title('How Many People Feel Safe After Measures To Protect Themselves')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()

#I think it would make more sense to show what measures peope are taking to present themselves before presenting the data on whether they feel safer afterwards

# %% [markdown]
# # Change in Life style - again change title to address larger issue or grab attention (Do people change their lifestyle in response to fear about crime?)
#
# Here we are trying to figure out how many people have changed their behaviour and routes because they are afraid of crime. The app could help them feel more secure and allow them the freedom to behave and travell freely.

# %%
#here we are analysing the change of routes and behaviour after experiencing a crime or being afraid of a crime
changeofbehaviour = gautengH[['Q1119Changed', 'Q1717Changebehaviour']]
avoidroute = gautengH[['Q11204Avoid']]
Routes = gautengS[['Q21a93ChangRoute']] 

# Selecting a count of all the yes and No responses for each colimn
yes = changeofbehaviour[changeofbehaviour == 1] .count() .sum()
no  = changeofbehaviour[changeofbehaviour == 2] .count() .sum()
yes1 = avoidroute[avoidroute == 1] .count() .sum()
no1  = avoidroute[avoidroute == 2] .count() .sum()
yes2 = Routes[Routes == 1] .count() .sum()
no2 = Routes[Routes == 2] .count() .sum()

#Adding all the yes responses and all the no responses
yes = yes + yes1 + yes2
no = no + no1 + no2
plot = yes, no

labels = ['Yes', 'No']
color = ['palegreen','crimson']

# Ploting it into a pie chart
plt.pie(plot, labels =labels, autopct='%1.0f%%', colors = color)
plt.title('How Many People Changed Routes and Behaviour') #people is spelt with e first, then o!
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()

#what is rationale behind combining these three, but not other categories?

# %% [markdown]
# # Avoiding certain places
#
# These people who decided to change avoid certain places, so that they are safe.

# %%
avoid = gautengS.groupby('Q21a94AvoidAreas') .size() 
avoid = avoid[0:2]

labels = ['Yes ', 'No']
color = ['palegreen','crimson']
#remove unspecified

plt.pie(avoid, labels =labels, autopct='%1.0f%%', colors = color )
plt.title('People Who Avoid Certain Areas') #change title: Do people avoid certain areas b/c of crime?
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()

# %% [markdown]
# # Police
#
# Here we will look at how much people trust the police, how reliable they think they are and how satisfied they were with reporting a crime.

# %%
police = gautengH[['Q372Police']]
police

plot = police.groupby('Q372Police') .size()
plot = plot[0:2]


labels = ['Yes', 'No']
color = ['palegreen','crimson']

plt.pie(plot, labels =labels, autopct='%1.0f%%', colors = color)
plt.title('Are Police Stations Accessible')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()

#change the plots below so that they are plotted together as subplots

# %%
police = gautengH[['Q421Police']]
police

plot = police.groupby('Q421Police') .size()
plot = plot[0:2]


labels = ['Yes', 'No']
color = ['palegreen','crimson']

plt.pie(plot, labels =labels, autopct='%1.0f%%', colors = color)
plt.title('Does The Police Station Have Medical Assistance')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()

# %%
reporting = gautengH[['Q114Report', 'Q127Report', 'Q1313Report', 'Q16a5Report', 'Q175Report','Q194Report','Q204Report' ]]
yes = reporting[reporting == 1] .count() .sum()
no  = reporting[reporting == 2] .count() .sum()
plot = yes, no

labels = ['Yes', 'No']
color = ['palegreen','crimson']

plt.pie(plot, labels =labels, autopct='%1.0f%%', colors = color)
plt.title('How Many People Went To Report At The Police Station')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()

# %%
satisfiedwithpolice = gautengH[['Q116Satisfied', 'Q129Satisfied', 'Q1315Satisfied', 'Q16a7Satisfied', 'Q177Satisfied', 'Q196Satisfied', 'Q206Satisfied']]
satisfiedwithpolice

yes = satisfiedwithpolice[satisfiedwithpolice == 1] .count() .sum()
no  = satisfiedwithpolice[satisfiedwithpolice == 2] .count() .sum()
plot = yes, no

labels = ['Yes', 'No']
color = ['palegreen','crimson']

plt.pie(plot, labels =labels, autopct='%1.0f%%', colors = color)
plt.title('How Many People Were Satisfied With The  Police Response')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()

# %%
satiswithhandling = gautengH[['Q12131Police','Q16a18Police', 'Q13191Police', 'Q11101Police','Q1711Police', 'Q1910Police', 'Q2010Police' ]]
satiswithhandling

yes = satiswithhandling[satiswithhandling == 1] .count() .sum()
no  = satiswithhandling[satiswithhandling == 2] .count() .sum()
plot = yes, no

labels = ['Yes', 'No']
color = ['palegreen','crimson']

plt.pie(plot, labels =labels, autopct='%1.0f%%', colors = color)
plt.title('How Many People Were Satisfied With The Way The Authority Handled The Case.')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()

# %% [markdown]
# # The Emergency Call
#
# Who is the first person you call when you are having an emergency or in danger?

# %%
firstcall = gautengH.groupby('Q36Victims') .size() .reset_index(name = 'number')
#we drop index 8 because it's the count of unspecified responses, which we want to ignore
firstcall = firstcall.drop(firstcall.index[8])

x = labels
y = firstcall['number']

labels = ['Nobody', 'Relative/friend', 'Private security companies', 'Community group/organisation', 
          'Religious/traditional Leader', 'SAPS', 'Metro police ', 'Community policing forum ']

plt.barh(x,y)
plt.xlabel('Frequency')
plt.title('Who Do People Call First When They Are In Danger Or An Emergency.')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()

# %% [markdown]
# When people are in danger they're more likely to call the South African Police Services (SAPS).

# %% [markdown]
# # Crimes

# %% [markdown]
# ### These are the most feared crimes.
#
# Rather say which are the most feared crimes.

# %%
feared_codes = ["Q2221Murder", "Q2222StrRob", "Q2223HomeRob", "Q2224BussRob", "Q2225Hijack", "Q2226Assault", "Q2227SexAssult", 
            "Q2228ChildAbuse", "Q2229Political", "Q22210Vigilante", "Q22211BagSnatch", 
            "Q22212Bicycle", "Q22213Car", "Q22214Burglary", "Q22215Crop", "Q22216Livestock", "Q22217WhiteCollar", "Q22218damage", 
            "Q22219IDtheft", "Q22220HumanTrafficking", "Q22221DrugTrafficking", "Q22222HateCrime", "Q22223Other"]

occur_codes = ["Q2211Murder", "Q2212StrRob", "Q2213HomeRob", "Q2214BussRob", "Q2215Hijack", "Q2216Assault", "Q2217SexAssult", 
            "Q2218ChildAbuse", "Q2219Political", "Q22110Vigilante", "Q22111BagSnatch", 
            "Q22112Bicycle", "Q22113Car", "Q22114Burglary", "Q22115Crop", "Q22116Livestock", "Q22117WhiteCollar", "Q22118damage", 
            "Q22119IDtheft", "Q22120HumanTrafficking", "Q22121DrugTrafficking", "Q22122HateCrime", "Q22123Other"]

# this list contains the labels of the crimes
crime_labels = ["Murder", "Street Robbery", "Home Roberry", "Business Robbery","Vehicle Hijacking", "Assault", "Sexual Assault", 
          "Child Abuse", "Political Violence", "Vigilantism", "Bag Snatching", "Bicycle Theft", "Vehicle Theft", "House Breaking", 
          "Crop Theft", "Livestock Theft", "White Collar", "Damage", "Id theft", "Human Trafficking", "Drug Trafficking",
          "Hate Crime", "Other Crime"]

# %%
def freqCount(region, topic_code, response_code):
    return region.groupby(topic_code).size().reset_index(name = 'frequency')['frequency'][response_code]

def multiFreqCount(region, occur_codes, response):
    crime_count = []
    for topic in occur_codes:
        crime_count.append(freqCount(gautengH, topic, response))
        
    return crime_count

plt.rcdefaults()
fig, fc = plt.subplots()

# Example data
y_pos = np.arange(len(crime_labels))

fc.barh(y_pos, multiFreqCount(gautengH, feared_codes, 0))
fc.set_yticks(y_pos)
fc.set_yticklabels(crime_labels)
fc.invert_yaxis()  # labels read top-to-bottom
fc.set_xlabel('Occurance')
fc.set_ylabel('Crimes Feared')
fc.set_title('Most feared crimes')
plt.show()

#sort these from highest to lowest

# %% [markdown]
# ### These are the crimes that people think occur most in their area.

# %%
plt.rcdefaults()
fig, fc = plt.subplots()

# Example data
y_pos = np.arange(len(crime_labels))

fc.barh(y_pos, multiFreqCount(gautengH, occur_codes, 0), color='red')
fc.set_yticks(y_pos)
fc.set_yticklabels(crime_labels)
fc.invert_yaxis()  # labels read top-to-bottom
fc.set_xlabel('Occurance')
fc.set_title('Most frequently occuring crimes')
plt.show()

#sort from highest to lowest

# %% [markdown]
# #### The perception is that Housebreaking is the most frequently occuring crime, followed by Street Robbery (Mugging), Home Robbery and Bag Snatching.
#
# NB:
# - Housebreaking is when a burglary occurs when there is no one in the house.
# - Home robbery is when there are people present in the house while the crime occurs.

# %% [markdown]
# ### Crime that were actually experience in the past 5 years.

# %%
crimes  = gautengS[['Q21b1aPersProp', 'Q21b11CarHijack', 'Q21b11cRob', 'Q21b1dSexual', 'Q21b1eAssault', 'Q21b1hOther']]

# %%
# Here I am grouping each crime to figure out how many people reported yes to experiencing each crime

persprop = crimes.groupby('Q21b1aPersProp') . size()
CarHij = crimes.groupby('Q21b11CarHijack') .size()
Rob = crimes.groupby('Q21b11cRob') .size()
SexualOff = crimes.groupby('Q21b1dSexual') .size()
Assualt = crimes.groupby('Q21b1eAssault') .size()
Other = crimes.groupby('Q21b1hOther') .size()

# %%
#These are all the "YES" cases
labels = ['Personal property','Car Hijacking','Sexual Offense','Assualt', 'Robbery']
counts = [persprop[1],CarHij[1],SexualOff[1],Assualt[1], Rob[1]]

plt.barh(labels, counts)
plt.xlabel('Occurance')
plt.title("Crimes That Were Experienced In Gauteng")
plt.show()

#sort from highest to lowest
